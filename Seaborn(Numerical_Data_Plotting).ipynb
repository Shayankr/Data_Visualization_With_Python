# %% [markdown]
# <a href="https://colab.research.google.com/github/Shayankr/Data_Visualization_With_Python/blob/master/Seaborn(Numerical_Data_Plotting).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Statistical analysis is a process of understanding how variables in a dataset relate to each-other and how those relationship depend on other variables.

# %% [markdown]
# Visualization can be a core-component of this process
# because when data are visualized properly, the human visual system can see trends and patterns that indicate a relationship.

# %% [markdown]
# 1. **Numerical Data Plotting**
# *   relplot()
# *   scatterplot()
# *   lineplot()

# %%
#importing libraries
import pandas as pd
import numpy as np

import seaborn as sns

import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# Press: Esc+B ---> to insert new cells below.

# %%
sns.set ( style='darkgrid')

# %%
# ?sns.set

# %%
#load dataset

sns.load_dataset("tips")
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
tips = sns.load_dataset('tips')

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
# relational plot

sns.relplot(x='total_bill', y='tip',data=tips)

# %%
dir(sns.FacetGrid)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_bottom_axes',
#  '_facet_color',
#  '_facet_plot',
#  '_finalize_grid',
#  '_get_palette',
#  '_inner_axes',
#  '_left_axes',
#  '_legend_out',
#  '_margin_titles',
#  '_not_bottom_axes',
#  '_not_left_axes',
#  '_update_legend_data',
#  'add_legend',
#  'ax',
#  'axes',
#  'axes_dict',
#  'despine',
#  'facet_axis',
#  'facet_data',
#  'fig',
#  'figure',
#  'legend',
#  'map',
#  'map_dataframe',
#  'refline',
#  'savefig',
#  'set',
#  'set_axis_labels',
#  'set_titles',
#  'set_xlabels',
#  'set_xticklabels',
#  'set_ylabels',
#  'set_yticklabels',
# ...

# %% [markdown]
# For, categorical palette

# %%
sns.relplot(x="total_bill", y="tip", data=tips, hue = "smoker") # categorical palettte

# %%
sns.relplot(x="total_bill", y="tip", hue="sex", data=tips)

# %%
sns.relplot(x="total_bill", y="tip", hue="time", data=tips)

# %%
sns.relplot(data=tips, x="total_bill", y="tip", hue="smoker", style="time")

# %% [markdown]
# now, for numerical color palette, qualiative palette, size increses color becomes darker and darker

# %%
sns.relplot(x="total_bill", y="tip", data=tips, hue="size")

# %% [markdown]
# palette

# %%
sns.relplot(x="total_bill", y="tip", data=tips, hue='size', palette='ch:r=-0.5, l=0.75')

# %%
# ?sns.relplot

# %%
sns.relplot(x="total_bill", y="tip", data=tips, style='size')

# %%
tips.sample(2)
# Out:
#     total_bill   tip     sex smoker  day    time  size
# 66       16.45  2.47  Female     No  Sat  Dinner     2
# 95       40.17  4.73    Male    Yes  Fri  Dinner     4

# %%
sns.relplot(x="total_bill", y='tip', data=tips, size='size',)

# %%
sns.relplot(x='total_bill', y='tip', data=tips, size='size', sizes=(15,200))

# %% [markdown]
# **LinePlot**

# %%
from numpy.random import randn

# %%
# Create DataFrame df
df = pd.DataFrame(dict(time=np.arange(500), value=randn(500).cumsum()))

# %%
#dict(time=np.arange(500), value=randn(500).cumsum())

# %%
# see few datas [5 rows]
df.sample(5)
# Out:
#      time      value
# 350   350 -19.813811
# 269   269 -25.338584
# 19     19   0.893190
# 391   391 -17.233703
# 425   425 -14.167904

# %% [markdown]
# sns.relplot() --> by default: kind='scatterplot'

# %%
sns.relplot(x='time', y='value', data=df)

# %%
sns.relplot(x='time',y='value', data=df, kind='line') #by default --> sort=True

# %%
df.columns
# Out:
# Index(['time', 'value'], dtype='object')

# %%
sns.relplot(x='time', y='value', data=df, kind='line', sort=False)

# %%
# Create new DataFrame

df = pd.DataFrame(randn(500,2).cumsum(axis=0), columns=['time','value'])
# See first 5 rows
df.head()
# Out:
#        time     value
# 0 -0.225359 -0.939253
# 1 -0.311981 -0.475632
# 2  0.330661  0.882261
# 3  0.569824 -2.267014
# 4  1.201528 -2.825345

# %%
sns.relplot(x='time', y='value', data=df, kind='line', sort=True)

# %%
sns.relplot(x='time', y='value', data=df, kind='line', sort=False)

# %%
sns.relplot(x='time', y='value', data=df, kind='line',) # by defalut --> sort=True

# %% [markdown]
# Now, load 'fMRI' datset
#
# Functional magnetic resonance imaging or functional MRI (fMRI) measures brain activity by detecting changes associated with blood flow. This technique relies on the fact that cerebral blood flow and neuronal activation are coupled.

# %% [markdown]
# <img src="https://upload.wikimedia.org/wikipedia/commons/4/4a/1206_FMRI.jpg" height=150, width=150/>

# %%
fmri = sns.load_dataset('fmri')

# %%
# look at first 5 rows:
fmri.head()
# Out:
#   subject  timepoint event    region    signal
# 0     s13         18  stim  parietal -0.017552
# 1      s5         14  stim  parietal -0.080883
# 2     s12         18  stim  parietal -0.081033
# 3     s11         18  stim  parietal -0.046134
# 4     s10         18  stim  parietal -0.037970

# %%
# dimensions of dataset
fmri.shape
# Out:
# (1064, 5)

# %%
sns.relplot(x='timepoint', y='signal', kind='line', data=fmri, )

# It also shows a line computed with 95% confident. (confidence-interval)--> S.D.

# %%
np.std(fmri)
# Out:
# timepoint    5.477226
# signal       0.093886
# dtype: float64

# %%
sns.relplot(x='timepoint', y='signal', kind='line', data=fmri, ci=False)

# %%
sns.relplot(x='timepoint', y='signal', data=fmri, kind='line', ci='sd')

# %%
sns.relplot(x='timepoint', y='signal', kind='line', data=fmri, estimator=None)

# %%
fmri['timepoint'].min(), fmri['timepoint'].max()
# Out:
# (0, 18)

# %%
fmri.columns
# Out:
# Index(['subject', 'timepoint', 'event', 'region', 'signal'], dtype='object')

# %%
fmri['event'].value_counts()
# Out:
# stim    532
# cue     532
# Name: event, dtype: int64

# %%
sns.relplot(x='timepoint', y='signal', hue='event', kind='line', data=fmri)
plt.show()

# %%
sns.relplot(x='timepoint', y='signal', size='event', kind='line', data=fmri)

# %%
sns.relplot(x='timepoint', y='signal', style='event', kind='line', data=fmri)

# %%
# check count of uniue values in region
fmri['region'].value_counts()
# Out:
# parietal    532
# frontal     532
# Name: region, dtype: int64

# %%
fmri['region'].unique()
# Out:
# array(['parietal', 'frontal'], dtype=object)

# %%
# take 'region' as hue and 'event' as style
sns.relplot(x='timepoint', y='signal', hue='region', style='event', kind='line', data=fmri)

# %%
# Now set [markers=True]
sns.relplot(x='timepoint', y='signal', hue='region', style='event', kind='line', data=fmri, markers=True) #markers are set into style

# %%
sns.relplot(x='timepoint', y='signal', hue='region', style='event', kind='line', data=fmri, markers=True, dashes=True)

# %%
sns.relplot(x='timepoint', y='signal', hue='region', style='event', kind='line', data=fmri, markers=True, dashes=False)

# %%
# now put hue and style on same variable 'event'
sns.relplot(x='timepoint', y='signal', data=fmri, kind='line', hue='event', style='event')

# %%
#sns.relplot(x='timepoint', y='signal', hue='region', units='subject', kind='line', data=fmri)
# ValueError: estimator must be None when specifying units

# %%
fmri.head(2)
# Out:
#   subject  timepoint event    region    signal
# 0     s13         18  stim  parietal -0.017552
# 1      s5         14  stim  parietal -0.080883

# %%
sns.relplot(x='timepoint', y='signal', hue='region', units='subject', estimator=None, kind='line',
            data=fmri)

# %%
sns.relplot(x='timepoint', y='signal', hue='region',  estimator=None, kind='line',
            data=fmri)  # remove units='subject'

# %%
fmri.columns
# Out:
# Index(['subject', 'timepoint', 'event', 'region', 'signal'], dtype='object')

# %%
fmri[fmri['event']=='stim'].count()
# Out:
# subject      532
# timepoint    532
# event        532
# region       532
# signal       532
# dtype: int64

# %%
# query data on fmri dataset
sns.relplot(x='timepoint', y='signal', hue='region', units='subject', estimator=None,
            kind='line', data=fmri.query("event=='stim' "))

# %%
sns.relplot(x='timepoint', y='signal', hue='region',
            kind='line', data=fmri.query("event=='stim' "))

# %% [markdown]
# Now, load another dataset 'dots'

# %%
dots = sns.load_dataset('dots')

# %%
# see random 3 rows
dots.sample(3)
# Out:
#     align choice  time  coherence  firing_rate
# 425  sacc     T1  -380        6.4    48.847411
# 51   dots     T1    80       12.8    33.744856
# 690  sacc     T2  -220       12.8    37.391940

# %%
# Now filter/ query dataset on some condition.

dots = sns.load_dataset('dots').query("align=='dots'")

# %%
dots.shape
# Out:
# (394, 5)

# %%
# see first 5 rows
dots.head()
# Out:
#   align choice  time  coherence  firing_rate
# 0  dots     T1   -80        0.0    33.189967
# 1  dots     T1   -80        3.2    31.691726
# 2  dots     T1   -80        6.4    34.279840
# 3  dots     T1   -80       12.8    32.631874
# 4  dots     T1   -80       25.6    35.060487

# %%
sns.relplot(x='time', y='firing_rate', data=dots, kind='line')

# %%
dots['coherence'].unique()
# Out:
# array([ 0. ,  3.2,  6.4, 12.8, 25.6, 51.2])

# %%
sns.relplot(x='time', y='firing_rate', data=dots, kind='line', hue='coherence')

# %%
dots.columns
# Out:
# Index(['align', 'choice', 'time', 'coherence', 'firing_rate'], dtype='object')

# %%
sns.relplot(x='time', y='firing_rate', data=dots, kind='line',
            hue='coherence', size='choice')

# %%
sns.relplot(x='time', y='firing_rate', data=dots, kind='line',
            hue='coherence', style='choice')

# %% [markdown]
# set palette

# %%
palette = sns.cubehelix_palette(n_colors=6, light=0.5)

# %%
palette
# Out:
# [[0.6672565752652589, 0.40671838146419587, 0.5620016466433286],
#  [0.57916573903086, 0.33934576125314425, 0.5219003947563425],
#  [0.48184548226856383, 0.27831554027596034, 0.47295182587901763],
#  [0.37894937987024996, 0.2224702044652721, 0.41140014301575434],
#  [0.2750134764306606, 0.1699640383194946, 0.3347740918539837],
#  [0.1750865648952205, 0.11840023306916837, 0.24215989137836502]]

# %%
sns.relplot(x='time', y='firing_rate', data=dots, kind='line', hue='coherence', style='choice', palette=palette)

# %%
dots['coherence'].unique()
# Out:
# array([ 0. ,  3.2,  6.4, 12.8, 25.6, 51.2])

# %%
sns.relplot(x='time', y='firing_rate', hue='coherence', size='coherence', style='choice',
            kind='line', data=dots)

# %%
# Vary the size in range of 1 to 5
sns.relplot(x='time', y='firing_rate', hue='coherence', size='coherence', style='choice',
            kind='line', data=dots, sizes=(1,5))

# %%
# Vary the size in range of 1 to 10
sns.relplot(x='time', y='firing_rate', hue='coherence', size='coherence', style='choice',
            kind='line', data=dots, sizes=(1,10))

# %% [markdown]
# Now, create a DataFrame 'df' with the help of dictionary having dateas keys and random numbers cummulative sum as values.

# %%
df = pd.DataFrame(dict(time=pd.date_range('2019-06-02','2022-01-19',periods=500), value=randn(500).cumsum()))

# %%
# see last 5 rows
df.tail()
# Out:
#                              time     value
# 495 2022-01-11 06:55:33.066132272  9.277180
# 496 2022-01-13 05:11:39.799599200  9.749784
# 497 2022-01-15 03:27:46.533066128  9.347878
# 498 2022-01-17 01:43:53.266533072  8.158982
# 499 2022-01-19 00:00:00.000000000  8.217979

# %%
sns.relplot(x='time', y='value', data=df)

# %%
sns.relplot(x='time', y='value', data=df, kind='line')

# %%
# Now, correct the alignment of "date-time" on x-axis

g= sns.relplot(x='time', y='value', kind='line', data=df)
g.fig.autofmt_xdate()

# %% [markdown]
# check available functions in "g.fig."

# %% [markdown]
# Now, 'tips' dataset

# %%
# see last 5 rows
tips.tail()
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2

# %%
sns.relplot(x='total_bill', y='tip', hue='smoker', data=tips)

# %% [markdown]
# Partition the graph column-wise based on a variable , here based on time as a 'lunch' or 'dinner

# %%
sns.relplot(x='total_bill', y='tip', hue='smoker', col='time', data=tips)

# %% [markdown]
# Partition the graph row-wise based on a variable , here based on time as a 'lunch' or 'dinner

# %%
sns.relplot(x='total_bill', y='tip', hue='smoker', data=tips, row='time')

# %% [markdown]
# Now, try more based on column-wise and row-wise

# %%
# row-wise
sns.relplot(x='total_bill', y='tip', hue='smoker', col='size', data=tips)

# %%
# column-wise
sns.relplot(x='total_bill', y='tip', hue='smoker', data=tips, row='size')

# %%
# row-wise, line-plot
sns.relplot(x='total_bill', y='tip', hue='smoker', col='size', data=tips, kind='line')

# %%
# Now, on 'fmri' datset
sns.relplot(x='timepoint', y='signal', hue='subject', col='region', 
            row='event', height=3, kind='line', estimator=None,
            data=fmri)

# %% [markdown]
# **Next,**

# %% [markdown]
#  **LinePlot , sns.lineplot()**

# %%
sns.lineplot(x='total_bill', y='tip', data=tips)

# %%
# 'fmri' dataset
sns.lineplot(x='timepoint', y='signal', hue='region', data=fmri)

# %%
sns.lineplot(x='timepoint', y='signal', hue='region', data=fmri,
             style='event')

# %%
sns.lineplot(x='timepoint', y='signal', hue='region', data=fmri,
             style='event', markers=True)

# %%
# remove confidence-interval
sns.lineplot(x='timepoint', y='signal', hue='region', data=fmri,
style='event', markers=True, ci=None)

# %%
# set specific confidence-interval
sns.lineplot(x='timepoint', y='signal', hue='region', data=fmri,
             style='event', markers=True, ci=68)

# %%
# change the err_style to 'bars'
sns.lineplot(x='timepoint', y='signal', hue='region', data=fmri,
             style='event', markers=True, ci=68, err_style='bars')

# %%
# query 'fmri' dataset based on region=='frontal'
sns.lineplot(x='timepoint', y='signal', hue='event', units='subject', estimator=None, 
             lw=1, data= fmri.query(" region == 'frontal' "))

# %%
# dots dataset

sns.lineplot(x='time', y='firing_rate', hue='coherence', style='choice',
             data = dots)

# %% [markdown]
# Now

# %% [markdown]
# **SCATTERPLOT**

# %% [markdown]
# **sns.scatterplot()**

# %%
sns.scatterplot(x='total_bill', y='tip', data=tips,)

# %%
sns.scatterplot(x='total_bill', y='tip', data=tips,
                hue='sex')

# %%
sns.scatterplot(x='total_bill', y='tip', data=tips,
                hue='smoker')

# %%
sns.relplot(x='total_bill', y='tip', data=tips,
            hue='smoker')

# %%
sns.scatterplot(x='total_bill', y='tip', data=tips,
                hue='smoker', size='size', style='time')

# %% [markdown]
# Now, try Iris-Dataset

# %%
iris= sns.load_dataset('iris')

# %%
# check any 5 rows
iris.sample(5)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width     species
# 14            5.8          4.0           1.2          0.2      setosa
# 11            4.8          3.4           1.6          0.2      setosa
# 58            6.6          2.9           4.6          1.3  versicolor
# 148           6.2          3.4           5.4          2.3   virginica
# 5             5.4          3.9           1.7          0.4      setosa

# %%
# Scatterplot

sns.scatterplot(x='sepal_length', y='petal_length', data=iris)

# %%
sns.scatterplot(x=iris['sepal_length'], y=iris['petal_length'])

# %% [markdown]
# **END**
