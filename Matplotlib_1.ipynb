# %% [markdown]
# Import some useful libraries, necessary for plotting

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# LIne Plot

# %%
plt.plot([1,2,3,4],[1,2,2,1])
plt.show()
